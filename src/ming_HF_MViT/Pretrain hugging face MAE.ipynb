# %%
# External packages
import torch
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import DataLoader
import time
import random
import numpy as np
import matplotlib.pyplot as plt

# our code
from src.utils.paths import *
from src.utils.device import get_optimal_device
from src.mvae.data_handler import (
    Animals10Dataset,
    PatchMasker,
    test_patch_masker
)
from src.shared_network_architectures.networks_pt import (
    MaskedAutoencoder,
    VisionTransformerEncoder,
    VisionTransformerDecoder
)



from transformers import ViTMAEConfig, ViTMAEModel
from transformers import AutoImageProcessor, ViTMAEForPreTraining

# Initializing a ViT MAE vit-mae-base style configuration
configuration = ViTMAEConfig(mask_ratio=0.5)
model_hf = ViTMAEForPreTraining(configuration)


from torch.utils.data import Subset


## Control
## Training
run_pretraining = True
check_masking = True
check_infilling = True
save_models = True
load_models = False

## Testing
# run_pretraining = False
# check_masking = True
# check_infilling = True
# save_models = False
# load_models = True

## Definitions
params = {
    # image
    "image_size": 224,  # number of pixels square
    "num_channels": 3,  #  RGB image -> 3 channels
    "patch_size": 16,  # must be divisor of image_size

    # vision transformer encoder
    "vit_num_features": 768,  # 768 number of features created by the vision transformer
    "vit_num_layers": 14, #12,  # 12ViT parameter
    "vit_num_heads": 8,  # 8 ViT parameter
    "vit_hidden_dim": 1024, #512,  # 512 ViT parameter
    "vit_mlp_dim": 2048, #1024,  # 1024 ViT parameter

    # vision transformer decoder
    "decoder_hidden_dim": 1024,  # 1024 ViT decoder first hidden layer dimension
    "decoder_CNN_channels": 16,  #
    "decoder_scale_factor": 4,  #

    # segmentation model
    "segmenter_hidden_dim": 128,
    "segmenter_classes": 3,  # image, background, boundary
}

report_every = 100

# Hyper-parameters
mask_ratio = 0.5
pt_batch_size = 8
pt_num_epochs = 5
pt_learning_rate = 0.00001  # 0.00001
# pt_momentum = 0.9  # not used, since using Adam optimizer
pt_step = 2
pt_gamma = 0.3

# file paths
data_dir = os.path.join(datasets_dir,"Animals-10/raw-img/")
model_file = "masked_autoencoder_model.pth"
encoder_file = "masked_autoencoder_encoder.pth"
decoder_file = "masked_autoencoder_decoder.pth"

# test image
test_image_path = os.path.join(data_dir, "image_0.png")

if __name__ == '__main__':

    # Set seeds for random number generator
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    model_path = os.path.join(models_dir, model_file)
    encoder_path = os.path.join(models_dir, encoder_file)
    decoder_path = os.path.join(models_dir, decoder_file)

    print(f"{data_dir = }\n{model_path = }\n{encoder_path = }\n{decoder_path = }\n{test_image_path = }")

    device = get_optimal_device()

    if params['image_size'] % params['patch_size'] != 0:
        raise ValueError("Alert! Patch size does not divide image size")

    num_patches = (params['image_size'] // params['patch_size']) ** 2
    num_masks = int(num_patches * mask_ratio)


    patch_masker = PatchMasker(params['patch_size'], num_masks)

    # Initializing a ViT MAE vit-mae-base style configuration
    configuration = ViTMAEConfig(mask_ratio=0.5)
    model_hf = ViTMAEForPreTraining(configuration)

    #####################
    # if a model has already been saved, load
    if load_models and os.path.isfile(model_path):
        print(f"Loading pre-saved vision-transformer model {model_file}")
        encoder.load_state_dict(torch.load(encoder_path), strict=False)
        decoder.load_state_dict(torch.load(decoder_path), strict=False)
        model_hf.load_state_dict(torch.load(model_path), strict=False)

    #####################
    # Demonstrate masking
    if check_masking:
        # original_image_tensor, masked_image_tensor = mask_tester(patch_masker, data_dir+"/cane/OIF-e2bexWrojgtQnAPPcUfOWQ.jpeg")
        original_image_tensor, masked_image_tensor = test_patch_masker(patch_masker, test_image_path)
        outputs=model_hf(original_image_tensor.unsqueeze(0))
        reconstruct=outputs.logits
        mask=outputs.mask

        # Visualize the results (assuming you have matplotlib installed)
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 4, 1)
        plt.axis('off')
        plt.imshow(original_image_tensor.squeeze(0).permute(1, 2, 0))  # Assuming image_tensor is in CHW format
        plt.title('Original Image')

        mask_=model_hf.unpatchify(mask[0].unsqueeze(-1).repeat(1, 1, model_hf.config.patch_size**2 *3))
        im_masked = original_image_tensor.squeeze(0) * (1 - mask_)
        plt.subplot(1, 4, 2)
        plt.axis('off')
        plt.imshow(im_masked.squeeze(0).permute(1, 2, 0))
        plt.title('Masked image')

        infill=model_hf.unpatchify(reconstruct)[0].detach()
        plt.subplot(1, 4, 3)
        plt.axis('off')
        plt.imshow(infill.squeeze(0).permute(1, 2, 0))  # Assuming inpainted_image_tensor is in CHW format
        plt.title('Infill Image')

        # MAE reconstruction pasted with visible patches
        im_paint = original_image_tensor * (1 - mask_) + infill * mask_
        plt.subplot(1, 4, 4)
        plt.axis('off')
        plt.imshow(im_paint.squeeze(0).permute(1, 2, 0))  # Assuming inpainted_image_tensor is in CHW format
        plt.title('Inpainted Image')

        plt.show()

    ###############
    #  mvae training
    if run_pretraining:
        print("In pre-training")
        start_time = time.perf_counter()
        model_hf.train()
        model_hf=model_hf.to(device)

        # Define loss function and optimizer
        pt_criterion = nn.MSELoss()
        pt_optimizer = torch.optim.Adam(model_hf.parameters(),lr=pt_learning_rate)
        scheduler = torch.optim.lr_scheduler.StepLR(pt_optimizer, step_size=pt_step, gamma=pt_gamma)

        # load and pre-process Animals-10 dataset and dataloader & transform to normalize the data
        transform = transforms.Compose([transforms.ToTensor()])

        dataset = Animals10Dataset(data_dir, (params['image_size'], params['image_size']), transform=transform)

        dataloader = DataLoader(dataset,
                                batch_size=pt_batch_size,
                                shuffle=True,
                                drop_last=True,
                                num_workers=2)  # drop last batch so that all batches are complete

        #use a subset of the data loader for debuging
        #subset_indices = range(100)
        #subset = Subset(dataloader.dataset, subset_indices)
        #dataloader = DataLoader(subset, batch_size=pt_batch_size, shuffle=True)

        # Main training loop
        losses = []
        for epoch in range(pt_num_epochs):
            model_hf.train()
            model_hf=model_hf.to(device)
            epoch_start_time = time.perf_counter()
            running_loss = 0.0
            for its, input_images in enumerate(dataloader):
                # print(f"[{its}, {len(dataloader)}] {time.perf_counter() - epoch_start_time:.0f}s")
                input_images = input_images.to(device)


                # Forward pass & compute the loss
                outputs = model_hf(input_images)
                infill=model_hf.unpatchify(outputs.logits)
                loss = pt_criterion(infill, input_images)

                # Backward pass and optimization
                pt_optimizer.zero_grad()
                loss.backward()
                pt_optimizer.step()

                running_loss += loss.detach().cpu().item()
                if its % report_every == (report_every - 1):  # print every report_every mini-batches
                    curr_time = time.perf_counter() - start_time
                    print('Epoch [%d / %d],  %d image minibatch [%4d / %4d], cumulative running loss: %.4f, uptime: %.2f' % (
                        epoch + 1, pt_num_epochs, pt_batch_size, its + 1, len(dataloader), running_loss / len(dataloader),
                        curr_time))
            scheduler.step()
            epoch_end_time = time.perf_counter()
            print(
                f"Epoch [{epoch + 1}/{pt_num_epochs}] completed in {(epoch_end_time - epoch_start_time):.0f}s, Loss: {running_loss / len(dataloader):.4f}")
            losses.append(running_loss / len(dataloader))

        ###############
        # Demonstrate infilling an image

            model_hf.eval()
            with torch.no_grad():
                model_hf=model_hf.to('cpu')
                outputs=model_hf(original_image_tensor.unsqueeze(0))
                reconstruct=outputs.logits
                mask=outputs.mask

            # Visualize the results (assuming you have matplotlib installed)
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 4, 1)
            plt.axis('off')
            plt.imshow(original_image_tensor.squeeze(0).permute(1, 2, 0))  # Assuming image_tensor is in CHW format
            plt.title('Original Image')

            mask_=model_hf.unpatchify(mask[0].unsqueeze(-1).repeat(1, 1, model_hf.config.patch_size**2 *3))
            im_masked = original_image_tensor.squeeze(0) * (1 - mask_)
            plt.subplot(1, 4, 2)
            plt.axis('off')
            plt.imshow(im_masked.squeeze(0).permute(1, 2, 0))
            plt.title('Masked image')

            infill=model_hf.unpatchify(reconstruct)[0].detach()
            plt.subplot(1, 4, 3)
            plt.axis('off')
            plt.imshow(infill.squeeze(0).permute(1, 2, 0))  # Assuming inpainted_image_tensor is in CHW format
            plt.title('Infill Image')

            # MAE reconstruction pasted with visible patches
            im_paint = original_image_tensor * (1 - mask_) + infill * mask_
            plt.subplot(1, 4, 4)
            plt.axis('off')
            plt.imshow(im_paint.squeeze(0).permute(1, 2, 0))  # Assuming inpainted_image_tensor is in CHW format
            plt.title('Inpainted Image')

            plt.show()

            date_str = time.strftime("_%H.%M_%d-%m-%Y", time.localtime(time.time()))
            plt.savefig(os.path.join(mvae_dir,'infilling' + date_str + '.png'))


        end_time = time.perf_counter()
        print(f"Masked VAE training finished after {(end_time - start_time):.0f}s")

        # Save the trained model & losses
        if save_models:
            torch.save(model_hf.state_dict(), model_path)


        date_str = time.strftime("_%H.%M_%d-%m-%Y", time.localtime(time.time()))
        with open(os.path.join(mvae_dir, "pt_losses" + date_str + ".txt"), 'w') as f:
            for i, loss in enumerate(losses):
                f.write(f'{i}  {loss}\n')
        print("Models saved\nFinished")
        print("Infilling finished")

    print("MVAE Script complete")
# Out:
# data_dir = '/content/drive/MyDrive/ADL/src/datasets/Animals-10/raw-img/'
# model_path = '/content/drive/MyDrive/ADL/src/models/masked_autoencoder_model.pth'
# encoder_path = '/content/drive/MyDrive/ADL/src/models/masked_autoencoder_encoder.pth'
# decoder_path = '/content/drive/MyDrive/ADL/src/models/masked_autoencoder_decoder.pth'
# test_image_path = '/content/drive/MyDrive/ADL/src/datasets/Animals-10/raw-img/image_0.png'
# Running on cuda
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# In pre-training
# Epoch [1 / 5],  8 image minibatch [ 100 / 3272], cumulative running loss: 0.0047, uptime: 343.64
# Epoch [1 / 5],  8 image minibatch [ 200 / 3272], cumulative running loss: 0.0066, uptime: 369.60
# Epoch [1 / 5],  8 image minibatch [ 300 / 3272], cumulative running loss: 0.0081, uptime: 395.19
# Epoch [1 / 5],  8 image minibatch [ 400 / 3272], cumulative running loss: 0.0093, uptime: 421.24
# Epoch [1 / 5],  8 image minibatch [ 500 / 3272], cumulative running loss: 0.0105, uptime: 447.60
# Epoch [1 / 5],  8 image minibatch [ 600 / 3272], cumulative running loss: 0.0115, uptime: 473.41
# Epoch [1 / 5],  8 image minibatch [ 700 / 3272], cumulative running loss: 0.0125, uptime: 499.27
# Epoch [1 / 5],  8 image minibatch [ 800 / 3272], cumulative running loss: 0.0135, uptime: 525.17
# Epoch [1 / 5],  8 image minibatch [ 900 / 3272], cumulative running loss: 0.0144, uptime: 551.09
# Epoch [1 / 5],  8 image minibatch [1000 / 3272], cumulative running loss: 0.0152, uptime: 577.03
# Epoch [1 / 5],  8 image minibatch [1100 / 3272], cumulative running loss: 0.0160, uptime: 602.95
# Epoch [1 / 5],  8 image minibatch [1200 / 3272], cumulative running loss: 0.0167, uptime: 628.87
# Epoch [1 / 5],  8 image minibatch [1300 / 3272], cumulative running loss: 0.0174, uptime: 654.76
# Epoch [1 / 5],  8 image minibatch [1400 / 3272], cumulative running loss: 0.0181, uptime: 680.65
# Epoch [1 / 5],  8 image minibatch [1500 / 3272], cumulative running loss: 0.0188, uptime: 706.57
# Epoch [1 / 5],  8 image minibatch [1600 / 3272], cumulative running loss: 0.0194, uptime: 732.46
# Epoch [1 / 5],  8 image minibatch [1700 / 3272], cumulative running loss: 0.0200, uptime: 758.36
# Epoch [1 / 5],  8 image minibatch [1800 / 3272], cumulative running loss: 0.0207, uptime: 784.24
# Epoch [1 / 5],  8 image minibatch [1900 / 3272], cumulative running loss: 0.0213, uptime: 810.12
# Epoch [1 / 5],  8 image minibatch [2000 / 3272], cumulative running loss: 0.0219, uptime: 836.02
# Epoch [1 / 5],  8 image minibatch [2100 / 3272], cumulative running loss: 0.0225, uptime: 861.89
# Epoch [1 / 5],  8 image minibatch [2200 / 3272], cumulative running loss: 0.0231, uptime: 887.78
# Epoch [1 / 5],  8 image minibatch [2300 / 3272], cumulative running loss: 0.0236, uptime: 913.66
# Epoch [1 / 5],  8 image minibatch [2400 / 3272], cumulative running loss: 0.0242, uptime: 939.55
# Epoch [1 / 5],  8 image minibatch [2500 / 3272], cumulative running loss: 0.0247, uptime: 965.42
# Epoch [1 / 5],  8 image minibatch [2600 / 3272], cumulative running loss: 0.0253, uptime: 991.30
# Epoch [1 / 5],  8 image minibatch [2700 / 3272], cumulative running loss: 0.0258, uptime: 1017.16
# Epoch [1 / 5],  8 image minibatch [2800 / 3272], cumulative running loss: 0.0264, uptime: 1043.02
# Epoch [1 / 5],  8 image minibatch [2900 / 3272], cumulative running loss: 0.0269, uptime: 1068.88
# Epoch [1 / 5],  8 image minibatch [3000 / 3272], cumulative running loss: 0.0275, uptime: 1094.75
# Epoch [1 / 5],  8 image minibatch [3100 / 3272], cumulative running loss: 0.0280, uptime: 1120.64
# Epoch [1 / 5],  8 image minibatch [3200 / 3272], cumulative running loss: 0.0285, uptime: 1146.53
# Epoch [1/5] completed in 1164s, Loss: 0.0289
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [2 / 5],  8 image minibatch [ 100 / 3272], cumulative running loss: 0.0005, uptime: 1192.60
# Epoch [2 / 5],  8 image minibatch [ 200 / 3272], cumulative running loss: 0.0010, uptime: 1218.58
# Epoch [2 / 5],  8 image minibatch [ 300 / 3272], cumulative running loss: 0.0016, uptime: 1244.53
# Epoch [2 / 5],  8 image minibatch [ 400 / 3272], cumulative running loss: 0.0021, uptime: 1270.46
# Epoch [2 / 5],  8 image minibatch [ 500 / 3272], cumulative running loss: 0.0026, uptime: 1296.39
# Epoch [2 / 5],  8 image minibatch [ 600 / 3272], cumulative running loss: 0.0031, uptime: 1322.32
# Epoch [2 / 5],  8 image minibatch [ 700 / 3272], cumulative running loss: 0.0036, uptime: 1348.22
# Epoch [2 / 5],  8 image minibatch [ 800 / 3272], cumulative running loss: 0.0041, uptime: 1374.14
# Epoch [2 / 5],  8 image minibatch [ 900 / 3272], cumulative running loss: 0.0046, uptime: 1400.05
# Epoch [2 / 5],  8 image minibatch [1000 / 3272], cumulative running loss: 0.0051, uptime: 1425.94
# Epoch [2 / 5],  8 image minibatch [1100 / 3272], cumulative running loss: 0.0056, uptime: 1451.82
# Epoch [2 / 5],  8 image minibatch [1200 / 3272], cumulative running loss: 0.0061, uptime: 1477.69
# Epoch [2 / 5],  8 image minibatch [1300 / 3272], cumulative running loss: 0.0065, uptime: 1503.59
# Epoch [2 / 5],  8 image minibatch [1400 / 3272], cumulative running loss: 0.0070, uptime: 1529.50
# Epoch [2 / 5],  8 image minibatch [1500 / 3272], cumulative running loss: 0.0075, uptime: 1555.41
# Epoch [2 / 5],  8 image minibatch [1600 / 3272], cumulative running loss: 0.0080, uptime: 1581.33
# Epoch [2 / 5],  8 image minibatch [1700 / 3272], cumulative running loss: 0.0085, uptime: 1607.31
# Epoch [2 / 5],  8 image minibatch [1800 / 3272], cumulative running loss: 0.0090, uptime: 1633.29
# Epoch [2 / 5],  8 image minibatch [1900 / 3272], cumulative running loss: 0.0094, uptime: 1659.23
# Epoch [2 / 5],  8 image minibatch [2000 / 3272], cumulative running loss: 0.0099, uptime: 1685.17
# Epoch [2 / 5],  8 image minibatch [2100 / 3272], cumulative running loss: 0.0104, uptime: 1711.07
# Epoch [2 / 5],  8 image minibatch [2200 / 3272], cumulative running loss: 0.0108, uptime: 1736.97
# Epoch [2 / 5],  8 image minibatch [2300 / 3272], cumulative running loss: 0.0113, uptime: 1762.85
# Epoch [2 / 5],  8 image minibatch [2400 / 3272], cumulative running loss: 0.0118, uptime: 1788.73
# Epoch [2 / 5],  8 image minibatch [2500 / 3272], cumulative running loss: 0.0122, uptime: 1814.60
# Epoch [2 / 5],  8 image minibatch [2600 / 3272], cumulative running loss: 0.0127, uptime: 1840.50
# Epoch [2 / 5],  8 image minibatch [2700 / 3272], cumulative running loss: 0.0132, uptime: 1866.41
# Epoch [2 / 5],  8 image minibatch [2800 / 3272], cumulative running loss: 0.0136, uptime: 1892.36
# Epoch [2 / 5],  8 image minibatch [2900 / 3272], cumulative running loss: 0.0141, uptime: 1918.32
# Epoch [2 / 5],  8 image minibatch [3000 / 3272], cumulative running loss: 0.0145, uptime: 1944.29
# Epoch [2 / 5],  8 image minibatch [3100 / 3272], cumulative running loss: 0.0150, uptime: 1970.23
# Epoch [2 / 5],  8 image minibatch [3200 / 3272], cumulative running loss: 0.0154, uptime: 1996.13
# Epoch [2/5] completed in 848s, Loss: 0.0158
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [3 / 5],  8 image minibatch [ 100 / 3272], cumulative running loss: 0.0004, uptime: 2042.34
# Epoch [3 / 5],  8 image minibatch [ 200 / 3272], cumulative running loss: 0.0009, uptime: 2068.32
# Epoch [3 / 5],  8 image minibatch [ 300 / 3272], cumulative running loss: 0.0013, uptime: 2094.28
# Epoch [3 / 5],  8 image minibatch [ 400 / 3272], cumulative running loss: 0.0017, uptime: 2120.21
# Epoch [3 / 5],  8 image minibatch [ 500 / 3272], cumulative running loss: 0.0022, uptime: 2146.11
# Epoch [3 / 5],  8 image minibatch [ 600 / 3272], cumulative running loss: 0.0026, uptime: 2172.01
# Epoch [3 / 5],  8 image minibatch [ 700 / 3272], cumulative running loss: 0.0030, uptime: 2197.94
# Epoch [3 / 5],  8 image minibatch [ 800 / 3272], cumulative running loss: 0.0035, uptime: 2223.89
# Epoch [3 / 5],  8 image minibatch [ 900 / 3272], cumulative running loss: 0.0039, uptime: 2249.81
# Epoch [3 / 5],  8 image minibatch [1000 / 3272], cumulative running loss: 0.0043, uptime: 2275.74
# Epoch [3 / 5],  8 image minibatch [1100 / 3272], cumulative running loss: 0.0048, uptime: 2301.69
# Epoch [3 / 5],  8 image minibatch [1200 / 3272], cumulative running loss: 0.0052, uptime: 2327.64
# Epoch [3 / 5],  8 image minibatch [1300 / 3272], cumulative running loss: 0.0056, uptime: 2353.60
# Epoch [3 / 5],  8 image minibatch [1400 / 3272], cumulative running loss: 0.0060, uptime: 2379.59
# Epoch [3 / 5],  8 image minibatch [1500 / 3272], cumulative running loss: 0.0065, uptime: 2405.57
# Epoch [3 / 5],  8 image minibatch [1600 / 3272], cumulative running loss: 0.0069, uptime: 2431.50
# Epoch [3 / 5],  8 image minibatch [1700 / 3272], cumulative running loss: 0.0073, uptime: 2457.41
# Epoch [3 / 5],  8 image minibatch [1800 / 3272], cumulative running loss: 0.0078, uptime: 2483.32
# Epoch [3 / 5],  8 image minibatch [1900 / 3272], cumulative running loss: 0.0082, uptime: 2509.23
# Epoch [3 / 5],  8 image minibatch [2000 / 3272], cumulative running loss: 0.0086, uptime: 2535.17
# Epoch [3 / 5],  8 image minibatch [2100 / 3272], cumulative running loss: 0.0090, uptime: 2561.12
# Epoch [3 / 5],  8 image minibatch [2200 / 3272], cumulative running loss: 0.0095, uptime: 2587.11
# Epoch [3 / 5],  8 image minibatch [2300 / 3272], cumulative running loss: 0.0099, uptime: 2613.05
# Epoch [3 / 5],  8 image minibatch [2400 / 3272], cumulative running loss: 0.0103, uptime: 2638.98
# Epoch [3 / 5],  8 image minibatch [2500 / 3272], cumulative running loss: 0.0107, uptime: 2664.91
# Epoch [3 / 5],  8 image minibatch [2600 / 3272], cumulative running loss: 0.0111, uptime: 2690.79
# Epoch [3 / 5],  8 image minibatch [2700 / 3272], cumulative running loss: 0.0116, uptime: 2716.73
# Epoch [3 / 5],  8 image minibatch [2800 / 3272], cumulative running loss: 0.0120, uptime: 2742.65
# Epoch [3 / 5],  8 image minibatch [2900 / 3272], cumulative running loss: 0.0124, uptime: 2768.61
# Epoch [3 / 5],  8 image minibatch [3000 / 3272], cumulative running loss: 0.0128, uptime: 2794.61
# Epoch [3 / 5],  8 image minibatch [3100 / 3272], cumulative running loss: 0.0133, uptime: 2820.54
# Epoch [3 / 5],  8 image minibatch [3200 / 3272], cumulative running loss: 0.0137, uptime: 2846.49
# Epoch [3/5] completed in 849s, Loss: 0.0140
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [4 / 5],  8 image minibatch [ 100 / 3272], cumulative running loss: 0.0004, uptime: 2892.64
# Epoch [4 / 5],  8 image minibatch [ 200 / 3272], cumulative running loss: 0.0008, uptime: 2918.63
# Epoch [4 / 5],  8 image minibatch [ 300 / 3272], cumulative running loss: 0.0012, uptime: 2944.62
# Epoch [4 / 5],  8 image minibatch [ 400 / 3272], cumulative running loss: 0.0016, uptime: 2970.54
# Epoch [4 / 5],  8 image minibatch [ 500 / 3272], cumulative running loss: 0.0021, uptime: 2996.46
# Epoch [4 / 5],  8 image minibatch [ 600 / 3272], cumulative running loss: 0.0025, uptime: 3022.41
# Epoch [4 / 5],  8 image minibatch [ 700 / 3272], cumulative running loss: 0.0029, uptime: 3048.45
# Epoch [4 / 5],  8 image minibatch [ 800 / 3272], cumulative running loss: 0.0033, uptime: 3074.41
# Epoch [4 / 5],  8 image minibatch [ 900 / 3272], cumulative running loss: 0.0037, uptime: 3100.29
# Epoch [4 / 5],  8 image minibatch [1000 / 3272], cumulative running loss: 0.0041, uptime: 3126.21
# Epoch [4 / 5],  8 image minibatch [1100 / 3272], cumulative running loss: 0.0045, uptime: 3152.23
# Epoch [4 / 5],  8 image minibatch [1200 / 3272], cumulative running loss: 0.0049, uptime: 3178.14
# Epoch [4 / 5],  8 image minibatch [1300 / 3272], cumulative running loss: 0.0053, uptime: 3204.11
# Epoch [4 / 5],  8 image minibatch [1400 / 3272], cumulative running loss: 0.0058, uptime: 3230.14
# Epoch [4 / 5],  8 image minibatch [1500 / 3272], cumulative running loss: 0.0062, uptime: 3256.08
# Epoch [4 / 5],  8 image minibatch [1600 / 3272], cumulative running loss: 0.0066, uptime: 3281.96
# Epoch [4 / 5],  8 image minibatch [1700 / 3272], cumulative running loss: 0.0070, uptime: 3307.98
# Epoch [4 / 5],  8 image minibatch [1800 / 3272], cumulative running loss: 0.0074, uptime: 3333.98
# Epoch [4 / 5],  8 image minibatch [1900 / 3272], cumulative running loss: 0.0078, uptime: 3359.86
# Epoch [4 / 5],  8 image minibatch [2000 / 3272], cumulative running loss: 0.0082, uptime: 3385.92
# Epoch [4 / 5],  8 image minibatch [2100 / 3272], cumulative running loss: 0.0086, uptime: 3411.93
# Epoch [4 / 5],  8 image minibatch [2200 / 3272], cumulative running loss: 0.0090, uptime: 3437.82
# Epoch [4 / 5],  8 image minibatch [2300 / 3272], cumulative running loss: 0.0094, uptime: 3463.74
# Epoch [4 / 5],  8 image minibatch [2400 / 3272], cumulative running loss: 0.0098, uptime: 3489.72
# Epoch [4 / 5],  8 image minibatch [2500 / 3272], cumulative running loss: 0.0102, uptime: 3515.71
# Epoch [4 / 5],  8 image minibatch [2600 / 3272], cumulative running loss: 0.0106, uptime: 3541.72
# Epoch [4 / 5],  8 image minibatch [2700 / 3272], cumulative running loss: 0.0110, uptime: 3567.72
# Epoch [4 / 5],  8 image minibatch [2800 / 3272], cumulative running loss: 0.0114, uptime: 3593.83
# Epoch [4 / 5],  8 image minibatch [2900 / 3272], cumulative running loss: 0.0119, uptime: 3619.85
# Epoch [4 / 5],  8 image minibatch [3000 / 3272], cumulative running loss: 0.0122, uptime: 3645.78
# Epoch [4 / 5],  8 image minibatch [3100 / 3272], cumulative running loss: 0.0127, uptime: 3671.68
# Epoch [4 / 5],  8 image minibatch [3200 / 3272], cumulative running loss: 0.0131, uptime: 3697.69
# Epoch [4/5] completed in 850s, Loss: 0.0134
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch [5 / 5],  8 image minibatch [ 100 / 3272], cumulative running loss: 0.0004, uptime: 3744.05
# Epoch [5 / 5],  8 image minibatch [ 200 / 3272], cumulative running loss: 0.0008, uptime: 3770.09
# Epoch [5 / 5],  8 image minibatch [ 300 / 3272], cumulative running loss: 0.0012, uptime: 3796.11
# Epoch [5 / 5],  8 image minibatch [ 400 / 3272], cumulative running loss: 0.0016, uptime: 3822.13
# Epoch [5 / 5],  8 image minibatch [ 500 / 3272], cumulative running loss: 0.0020, uptime: 3848.22
# Epoch [5 / 5],  8 image minibatch [ 600 / 3272], cumulative running loss: 0.0024, uptime: 3874.30
# Epoch [5 / 5],  8 image minibatch [ 700 / 3272], cumulative running loss: 0.0028, uptime: 3900.24
# Epoch [5 / 5],  8 image minibatch [ 800 / 3272], cumulative running loss: 0.0032, uptime: 3926.13
# Epoch [5 / 5],  8 image minibatch [ 900 / 3272], cumulative running loss: 0.0036, uptime: 3952.11
# Epoch [5 / 5],  8 image minibatch [1000 / 3272], cumulative running loss: 0.0040, uptime: 3978.11
# Epoch [5 / 5],  8 image minibatch [1100 / 3272], cumulative running loss: 0.0044, uptime: 4004.04
# Epoch [5 / 5],  8 image minibatch [1200 / 3272], cumulative running loss: 0.0048, uptime: 4029.94
# Epoch [5 / 5],  8 image minibatch [1300 / 3272], cumulative running loss: 0.0052, uptime: 4055.91
# Epoch [5 / 5],  8 image minibatch [1400 / 3272], cumulative running loss: 0.0055, uptime: 4081.98
# Epoch [5 / 5],  8 image minibatch [1500 / 3272], cumulative running loss: 0.0059, uptime: 4107.92
# Epoch [5 / 5],  8 image minibatch [1600 / 3272], cumulative running loss: 0.0063, uptime: 4133.78
# Epoch [5 / 5],  8 image minibatch [1700 / 3272], cumulative running loss: 0.0067, uptime: 4159.74
# Epoch [5 / 5],  8 image minibatch [1800 / 3272], cumulative running loss: 0.0071, uptime: 4185.64
# Epoch [5 / 5],  8 image minibatch [1900 / 3272], cumulative running loss: 0.0075, uptime: 4211.60
# Epoch [5 / 5],  8 image minibatch [2000 / 3272], cumulative running loss: 0.0079, uptime: 4237.59
# Epoch [5 / 5],  8 image minibatch [2100 / 3272], cumulative running loss: 0.0083, uptime: 4263.62
# Epoch [5 / 5],  8 image minibatch [2200 / 3272], cumulative running loss: 0.0087, uptime: 4289.59
# Epoch [5 / 5],  8 image minibatch [2300 / 3272], cumulative running loss: 0.0091, uptime: 4315.55
# Epoch [5 / 5],  8 image minibatch [2400 / 3272], cumulative running loss: 0.0095, uptime: 4341.49
# Epoch [5 / 5],  8 image minibatch [2500 / 3272], cumulative running loss: 0.0099, uptime: 4367.43
# Epoch [5 / 5],  8 image minibatch [2600 / 3272], cumulative running loss: 0.0103, uptime: 4393.35
# Epoch [5 / 5],  8 image minibatch [2700 / 3272], cumulative running loss: 0.0107, uptime: 4419.23
# Epoch [5 / 5],  8 image minibatch [2800 / 3272], cumulative running loss: 0.0110, uptime: 4445.18
# Epoch [5 / 5],  8 image minibatch [2900 / 3272], cumulative running loss: 0.0114, uptime: 4471.13
# Epoch [5 / 5],  8 image minibatch [3000 / 3272], cumulative running loss: 0.0118, uptime: 4497.18
# Epoch [5 / 5],  8 image minibatch [3100 / 3272], cumulative running loss: 0.0122, uptime: 4523.17
# Epoch [5 / 5],  8 image minibatch [3200 / 3272], cumulative running loss: 0.0126, uptime: 4549.21
# Epoch [5/5] completed in 850s, Loss: 0.0129
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Masked VAE training finished after 4569s
# Models saved
# Finished
# Infilling finished
# MVAE Script complete
